# %%
import csv
import pandas as pd
import search_process
import visualization_process
import interface
import matplotlib.pyplot as plt
# %matplotlib inline

print('Welcome to Pandots Autos Information System')
def loadData():
    interface.started_operation('loading data...')
    print('Please Enter: "CarPrice.csv"') 
    file_path='CarPrice.csv'
    while True:
        try:
            file_path= input('Enter the stated file path to load data: ')
            car_data = pd.read_csv (file_path)
            break
        except IOError:
            print("File not found")
            print("Enter a valid file name")
    interface.completed_operation()
def run():
    car_data = loadData()

    while True:
        selection = interface.menu()
        if selection == "i":
            search_process.searchById()
        elif selection == "ii":
            search_process.searchByCylinder()
        elif selection == "iii":
            search_process.searchByBody()
        elif selection == "iv":
            search_process.specificColumn()
        elif selection == "v":
            search_process.alphabetically()
        elif selection == "vi":
            search_process.salesSummary()
        elif selection == "vii":
            search_process.topSaleByBody()
        elif selection == "viii":
            search_process.covertibleAbove1500()
        elif selection == "ix":
            visualization_process.displayCarPerFuelSystem()
        elif selection == "x":
            visualization_process.horsepowerSubplot()
        elif selection == "xi":
            visualization_process.displaySalesPercent()
        elif selection == "exit":
            break
        else:
            interface.error("Invalid Selection!")
if __name__ == "__main__":
    run()
# Out:
# Welcome to Pandots Autos Information System
# ..........................................................................................
# Started: loading data......
#
# Please Enter: "CarPrice.csv"
# Enter the stated file path to load data: CarPric.csv
# File not found
# Enter a valid file name
# Enter the stated file path to load data: CarPrice.csv
#
# Completed.
# ..........................................................................................
#
# Please select one of the following options:
#     [i]      Search by car ID
#     [ii]     Search car by Cylinder
#     [iii]    Search car by Body
#     [iv]     Retrieve vital columns
#     [v]      Sort car names alphabetically
#     [vi]     Retrieve summary of sales for each car body
#     [vii]    Retrieve the top 5 car sale by price and per car body
#     [viii]   Retrieve the detail of cars based on your own selection
#     [ix]     Display cars per fuel system using a bar chart
# ...
